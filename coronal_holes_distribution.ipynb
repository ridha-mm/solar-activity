# %% [markdown]
# <a href="https://colab.research.google.com/github/Ridha273/solar-activity/blob/main/coronal_holes_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.axes as ax
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from astropy.io import ascii
from astropy.visualization import time_support

# %%
data = ascii.read('coronal-hole-data.csv')
lat = ascii.read('ch-lat-mean.csv')

# %%
plt.hist(data['lat'], bins=18, color='dimgray')
plt.xlabel('Latitude (degrees)')
plt.ylabel("Number of CH's")

# %%
time_support()

plt.scatter(Time(data['time'],format='isot'), data['lat'], c = 'dimgray', s=1, edgecolors='None')
plt.plot(Time(lat['time'],format='isot'), lat['s-avg'], color='blue')
plt.plot(Time(lat['time'],format='isot'), lat['n-avg'], color='red')

plt.xlabel('Years')
plt.ylabel('Latitude (degrees)')

fig.tight_layout()  # otherwise the right y-label is slightly clipped

# %%
time_support()

plt.scatter(Time(t,format='isot'), x, c = 'dimgray', s=1, edgecolors='None')
plt.xlabel('Year')
plt.ylabel('Carrington longitude (degrees)')
plt.savefig("ch-long-time-combined.png",dpi=300)
plt.show()
